# %%
import pandas as pd

# %%
df=pd.read_csv('nse_data.csv')
df.head() # it will not show all data but give overview of data how it is
# Out:
#        SYMBOL  SERIES         DATE1   PREV_CLOSE   OPEN_PRICE   HIGH_PRICE  \
# 0   20MICRONS      EQ   22-Jun-2022        64.55        63.20        66.85
# 1  21STCENMGM      EQ   22-Jun-2022        22.80        23.25        23.25
# 2   3IINFOLTD      EQ   22-Jun-2022        39.70        40.50        40.50
# 3     3MINDIA      EQ   22-Jun-2022     19987.40     19900.00     19900.00
# 4      3PLAND      EQ   22-Jun-2022        14.15        13.45        14.45
#
#     LOW_PRICE   LAST_PRICE   CLOSE_PRICE   AVG_PRICE   TTL_TRD_QNTY  \
# 0       62.60        65.00         63.70       64.50          86862
# 1       23.25        23.25         23.25       23.25              4
# 2       39.25        39.40         39.60       39.68         210847
# 3    19634.85     19899.90      19764.85    19799.33          54194
# 4       13.45        13.65         14.00       13.81           4985
#
#     TURNOVER_LACS   NO_OF_TRADES  DELIV_QTY  DELIV_PER
# ...
